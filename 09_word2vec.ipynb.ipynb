# %% [markdown]
# # Word2Vec: Learning Word Embeddings on a Small Spam Dataset
#
# **Goal:** Learn how to convert text messages into dense vector embeddings using Word2Vec.
#
# **Why Word2Vec?**
#
# - Bag of Words (BoW) and TF-IDF:
#   - Sparse vectors
#   - Ignore semantic meaning
#   - Treat words independently
#
# - Word2Vec:
#   - Dense embeddings
#   - Captures semantic relationships (king - man + woman ≈ queen)
#   - Uses context (CBOW or Skip-gram)
#
# **Dataset:** Small sample from `spam.csv`
# - Column `v2` contains text messages
# - Column `v1` contains labels (`ham`/`spam`) → ignored for Word2Vec
# - 20 short, real-world messages → ideal for learning

# %%
# Import libraries
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from gensim.models import Word2Vec, KeyedVectors

# Download punkt tokenizer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     D:\miniconda_setup\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Load the small dataset
df = pd.read_csv('spam.csv', encoding='latin-1')

# Take first 20 messages
df_small = df[['v2']].head(20)

# Display first few messages
df_small
# Out:
#                                                    v2
# 0   Go until jurong point, crazy.. Available only ...
# 1                       Ok lar... Joking wif u oni...
# 2   Free entry in 2 a wkly comp to win FA Cup fina...
# 3   U dun say so early hor... U c already then say...
# 4   Nah I don't think he goes to usf, he lives aro...
# 5   FreeMsg Hey there darling it's been 3 week's n...
# 6   Even my brother is not like to speak with me. ...
# 7   As per your request 'Melle Melle (Oru Minnamin...
# 8   WINNER!! As a valued network customer you have...
# 9   Had your mobile 11 months or more? U R entitle...
# 10  I'm gonna be home soon and i don't want to tal...
# 11  SIX chances to win CASH! From 100 to 20,000 po...
# 12  URGENT! You have won a 1 week FREE membership ...
# 13  I've been searching for the right words to tha...
# 14                I HAVE A DATE ON SUNDAY WITH WILL!!
# 15  XXXMobileMovieClub: To use your credit, click ...
# 16                         Oh k...i'm watching here:)
# 17  Eh u remember how 2 spell his name... Yes i di...
# 18  Fine if thatåÕs the way u feel. ThatåÕs the wa...
# 19  England v Macedonia - dont miss the goals/team...

# %% [markdown]
# **Explanation:**
#
# - The dataset contains short messages (`v2`) with labels (`v1`)
# - For Word2Vec, we **only need the text (`v2`)**
# - Labels (`ham`/`spam`) will be ignored

# %% [markdown]
# ## Text Preprocessing

# %%
# Combine all 20 messages into one string
text = " ".join(df_small['v2'].astype(str))

# Clean text: lowercase & remove punctuation/numbers
text_clean = re.sub(r'[^a-z\s]', '', text.lower())

# Tokenize into sentences, then words
sentences = [word_tokenize(sent) for sent in sent_tokenize(text_clean)]

# Show sample tokenized sentences
print("Sample tokenized sentences:", sentences[:3])
# Out:
# Sample tokenized sentences: [['go', 'until', 'jurong', 'point', 'crazy', 'available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'there', 'got', 'amore', 'wat', 'ok', 'lar', 'joking', 'wif', 'u', 'oni', 'free', 'entry', 'in', 'a', 'wkly', 'comp', 'to', 'win', 'fa', 'cup', 'final', 'tkts', 'st', 'may', 'text', 'fa', 'to', 'to', 'receive', 'entry', 'questionstd', 'txt', 'ratetcs', 'apply', 'overs', 'u', 'dun', 'say', 'so', 'early', 'hor', 'u', 'c', 'already', 'then', 'say', 'nah', 'i', 'dont', 'think', 'he', 'goes', 'to', 'usf', 'he', 'lives', 'around', 'here', 'though', 'freemsg', 'hey', 'there', 'darling', 'its', 'been', 'weeks', 'now', 'and', 'no', 'word', 'back', 'id', 'like', 'some', 'fun', 'you', 'up', 'for', 'it', 'still', 'tb', 'ok', 'xxx', 'std', 'chgs', 'to', 'send', 'to', 'rcv', 'even', 'my', 'brother', 'is', 'not', 'like', 'to', 'speak', 'with', 'me', 'they', 'treat', 'me', 'like', 'aids', 'patent', 'as', 'per', 'your', 'request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'has', 'been', 'set', 'as', 'your', 'callertune', 'for', 'all', 'callers', 'press', 'to', 'copy', 'your', 'friends', 'callertune', 'winner', 'as', 'a', 'valued', 'network', 'customer', 'you', 'have', 'been', 'selected', 'to', 'receivea', 'prize', 'reward', 'to', 'claim', 'call', 'claim', 'code', 'kl', 'valid', 'hours', 'only', 'had', 'your', 'mobile', 'months', 'or', 'more', 'u', 'r', 'entitled', 'to', 'update', 'to', 'the', 'latest', 'colour', 'mobiles', 'with', 'camera', 'for', 'free', 'call', 'the', 'mobile', 'update', 'co', 'free', 'on', 'im', 'gon', 'na', 'be', 'home', 'soon', 'and', 'i', 'dont', 'want', 'to', 'talk', 'about', 'this', 'stuff', 'anymore', 'tonight', 'k', 'ive', 'cried', 'enough', 'today', 'six', 'chances', 'to', 'win', 'cash', 'from', 'to', 'pounds', 'txt', 'csh', 'and', 'send', 'to', 'cost', 'pday', 'days', 'tsandcs', 'apply', 'reply', 'hl', 'info', 'urgent', 'you', 'have', 'won', 'a', 'week', 'free', 'membership', 'in', 'our', 'prize', 'jackpot', 'txt', 'the', 'word', 'claim', 'to', 'no', 'tc', 'wwwdbuknet', 'lccltd', 'pobox', 'ldnwarw', 'ive', 'been', 'searching', 'for', 'the', 'right', 'words', 'to', 'thank', 'you', 'for', 'this', 'breather', 'i', 'promise', 'i', 'wont', 'take', 'your', 'help', 'for', 'granted', 'and', 'will', 'fulfil', 'my', 'promise', 'you', 'have', 'been', 'wonderful', 'and', 'a', 'blessing', 'at', 'all', 'times', 'i', 'have', 'a', 'date', 'on', 'sunday', 'with', 'will', 'xxxmobilemovieclub', 'to', 'use', 'your', 'credit', 'click', 'the', 'wap', 'link', 'in', 'the', 'next', 'txt', 'message', 'or', 'click', 'here', 'httpwap', 'xxxmobilemovieclubcomnqjkgighjjgcbl', 'oh', 'kim', 'watching', 'here', 'eh', 'u', 'remember', 'how', 'spell', 'his', 'name', 'yes', 'i', 'did', 'he', 'v', 'naughty', 'make', 'until', 'i', 'v', 'wet', 'fine', 'if', 'thats', 'the', 'way', 'u', 'feel', 'thats', 'the', 'way', 'its', 'gota', 'b', 'england', 'v', 'macedonia', 'dont', 'miss', 'the', 'goalsteam', 'news', 'txt', 'ur', 'national', 'team', 'to', 'eg', 'england', 'to', 'trywales', 'scotland', 'txt', 'poboxoxwwq']]

# %% [markdown]
# **Explanation:**
#
# - Lowercase all text → standardize words
# - Remove punctuation/numbers → Word2Vec only needs words
# - Sentence tokenization → split text into sentences
# - Word tokenization → split sentences into individual words (tokens)
# - `sentences` is a **list of lists**, ready for Word2Vec

# %% [markdown]
# ## Train Custom Word2Ve

# %%
# Train Word2Vec model
custom_model = Word2Vec(
    sentences,
    vector_size=50,
    window=5,
    min_count=1,
    sg=0
)

print("Custom Word2Vec model trained!")
# Out:
# Custom Word2Vec model trained!

# %% [markdown]
# **Explanation:**
#
# - `vector_size=50` → each word is a 50-dimensional vector
# - `window=5` → looks at 5 words before and after target
# - `min_count=1` → keeps all words
# - `sg=0` → CBOW (predict target from context)
# - The model is **kept in memory** for learning and exploration

# %%
# Vector for the word 'free'
print("Vector for 'free':\n", custom_model.wv['free'])

# Most similar words to 'free'
print("Words most similar to 'free':\n", custom_model.wv.most_similar('free'))
# Out:
# Vector for 'free':
#  [-0.00042949 -0.01769441 -0.0171706   0.00560984 -0.01630914 -0.01817991
#  -0.00456867 -0.01697105 -0.01432883 -0.01687582 -0.0005864  -0.00941468
#   0.01330951  0.0032145  -0.00664493  0.01230546 -0.01190136 -0.00931185
#  -0.01450581 -0.00868222 -0.00354911  0.0131164  -0.00541984  0.0096872
#   0.01395269 -0.01488608  0.00903487  0.01216818 -0.0058824   0.01324652
#   0.01227542 -0.01281739 -0.01361191  0.0051191  -0.00333173 -0.01197002
#   0.01918649 -0.01017233 -0.01296445 -0.00031145 -0.00513106  0.00092714
#  -0.00711915 -0.00084244 -0.00121083  0.00171802  0.01633341 -0.01154558
#  -0.00341097  0.01115458]
# Words most similar to 'free':
#  [('id', 0.49181419610977173), ('fine', 0.4748515784740448), ('your', 0.3071158528327942), ('scotland', 0.3011452257633209), ('amore', 0.2860356569290161), ('hl', 0.2728937864303589), ('dont', 0.2691073715686798), ('early', 0.2579798102378845), ('sunday', 0.25507038831710815), ('wkly', 0.25023606419563293)]

# %%
# Get all words in vocabulary
unique_words = list(custom_model.wv.index_to_key)

# Loop through each word
for word in unique_words:
    vector = custom_model.wv[word]                 # 50D vector
    similar_words = custom_model.wv.most_similar(word, topn=5)  # top 5 similar words
    print(f"\nWord: {word}")
    print(f"Vector (first 5 dims shown): {vector[:5]} ...")  # snippet
    print(f"Top 5 similar words: {similar_words}")
# Out:
# Word: to
# Vector (first 5 dims shown): [-0.00099044  0.00044592  0.01032321  0.01804609 -0.01848899] ...
# Top 5 similar words: [('dun', 0.3258264362812042), ('credit', 0.32306140661239624), ('gota', 0.3029196262359619), ('amore', 0.2749740481376648), ('dont', 0.2742103040218353)]
#
# Word: the
# Vector (first 5 dims shown): [-0.0161322   0.00906084 -0.00819695  0.00157982  0.01717829] ...
# Top 5 similar words: [('remember', 0.4195212423801422), ('this', 0.37753814458847046), ('wat', 0.302047461271286), ('fine', 0.2724485695362091), ('info', 0.2646276354789734)]
#
# Word: i
# Vector (first 5 dims shown): [-0.01711326  0.00738902  0.01049401  0.01144767  0.01516186] ...
# Top 5 similar words: [('goalsteam', 0.37226977944374084), ('help', 0.355258584022522), ('oru', 0.34388771653175354), ('httpwap', 0.33819687366485596), ('has', 0.32935234904289246)]
#
# Word: u
# Vector (first 5 dims shown): [ 0.01578102 -0.01901144 -0.00028401  0.00688657 -0.00170458] ...
# Top 5 similar words: [('code', 0.31285619735717773), ('it', 0.30046549439430237), ('callers', 0.29314056038856506), ('wonderful', 0.2773377299308777), ('k', 0.2630273401737213)]
#
# Word: for
# Vector (first 5 dims shown): [ 0.00030644  0.00614061 -0.01359592 -0.00271014  0.0154147 ] ...
# Top 5 similar words: [('receivea', 0.40354618430137634), ('they', 0.3702854812145233), ('lccltd', 0.3578523099422455), ('joking', 0.356295645236969), ('news', 0.3552634119987488)]
#
# Word: your
# Vector (first 5 dims shown): [ 0.00288693 -0.00529821 -0.01412241 -0.01563205 -0.01811914] ...
# Top 5 similar words: [('wet', 0.367190957069397), ('copy', 0.351839154958725), ('call', 0.3202859163284302), ('b', 0.3125355541706085), ('free', 0.307115763425827)]
#
# Word: txt
# Vector (first 5 dims shown): [-0.01636393  0.01860185 -0.00027456 -0.00397685  0.00930927] ...
# Top 5 similar words: [('already', 0.38812902569770813), ('oni', 0.33109402656555176), ('credit', 0.3007228970527649), ('use', 0.27657264471054077), ('update', 0.27157270908355713)]
#
# Word: a
# Vector (first 5 dims shown): [ 0.00867051  0.00010989 -0.01918314 -0.01934494 -0.0121554 ] ...
# Top 5 similar words: [('next', 0.35302209854125977), ('reply', 0.321016788482666), ('at', 0.3031574785709381), ('wap', 0.2532885670661926), ('credit', 0.25040698051452637)]
#
# Word: been
# Vector (first 5 dims shown): [-0.01418882  0.00248164 -0.01435935 -0.00452872  0.00751992] ...
# Top 5 similar words: [('my', 0.31435060501098633), ('available', 0.3132781982421875), ('want', 0.31185558438301086), ('ldnwarw', 0.3059675097465515), ('next', 0.28749772906303406)]
#
# Word: you
# Vector (first 5 dims shown): [ 0.00814961  0.00869802  0.01996615 -0.00896364 -0.00265115] ...
# Top 5 similar words: [('b', 0.40386685729026794), ('scotland', 0.38290438055992126), ('questionstd', 0.333821564912796), ('about', 0.32031434774398804), ('darling', 0.31853625178337097)]
#
# Word: and
# Vector (first 5 dims shown): [-0.01737844  0.00426711 -0.00170104 -0.01867219 -0.0187486 ] ...
# Top 5 similar words: [('xxxmobilemovieclub', 0.3768960237503052), ('vettam', 0.326821893453598), ('from', 0.3253514766693115), ('feel', 0.29613277316093445), ('c', 0.2860781252384186)]
#
# Word: have
# Vector (first 5 dims shown): [ 0.00555926 -0.01673154  0.01568724  0.01708202 -0.01901068] ...
# Top 5 similar words: [('here', 0.5312193632125854), ('poboxoxwwq', 0.3132701516151428), ('copy', 0.3099723756313324), ('fa', 0.30882570147514343), ('until', 0.29137179255485535)]
#
# Word: in
# Vector (first 5 dims shown): [ 0.01638008 -0.00888671 -0.00203904  0.00202172 -0.00024948] ...
# Top 5 similar words: [('some', 0.3640008568763733), ('remember', 0.32433339953422546), ('granted', 0.2964021563529968), ('feel', 0.2958153784275055), ('poboxoxwwq', 0.2724592983722687)]
#
# Word: free
# Vector (first 5 dims shown): [-0.00042949 -0.01769441 -0.0171706   0.00560984 -0.01630914] ...
# Top 5 similar words: [('id', 0.49181419610977173), ('fine', 0.4748515784740448), ('your', 0.3071158528327942), ('scotland', 0.3011452257633209), ('amore', 0.2860356569290161)]
#
# Word: here
# Vector (first 5 dims shown): [ 0.01644906 -0.00880999  0.01809591  0.01643624 -0.00870845] ...
# Top 5 similar words: [('have', 0.5312194228172302), ('treat', 0.4482857882976532), ('until', 0.43136337399482727), ('fa', 0.3978220522403717), ('copy', 0.38094362616539)]
#
# Word: with
# Vector (first 5 dims shown): [-0.0173151  -0.00294069  0.01898372 -0.01513328 -0.01064983] ...
# Top 5 similar words: [('wwwdbuknet', 0.4463292956352234), ('talk', 0.38560330867767334), ('pday', 0.38078638911247253), ('will', 0.32031163573265076), ('mobiles', 0.31283143162727356)]
#
# Word: as
# Vector (first 5 dims shown): [-0.01907259  0.01783854  0.00831922  0.01841805  0.01334687] ...
# Top 5 similar words: [('from', 0.33725735545158386), ('crazy', 0.3147205412387848), ('poboxoxwwq', 0.31046169996261597), ('it', 0.3037292957305908), ('pday', 0.29810822010040283)]
#
# Word: v
# Vector (first 5 dims shown): [-1.5055780e-05  5.4275536e-04 -1.9779362e-04 -9.6045695e-03
#   8.7391343e-03] ...
# Top 5 similar words: [('take', 0.42954832315444946), ('it', 0.38148006796836853), ('has', 0.372889906167984), ('ldnwarw', 0.3601139783859253), ('jurong', 0.33911287784576416)]
#
# Word: dont
# Vector (first 5 dims shown): [-0.01021411 -0.01333431 -0.01543912  0.01656959 -0.00384553] ...
# Top 5 similar words: [('ok', 0.436854749917984), ('crazy', 0.41955098509788513), ('fine', 0.4097897708415985), ('remember', 0.3788759410381317), ('yes', 0.36661240458488464)]
#
# Word: claim
# Vector (first 5 dims shown): [ 0.00521576  0.0161787  -0.00276201  0.01615359  0.00749431] ...
# Top 5 similar words: [('xxxmobilemovieclubcomnqjkgighjjgcbl', 0.3529072105884552), ('info', 0.2847927212715149), ('questionstd', 0.2653215825557709), ('kl', 0.2567625343799591), ('oh', 0.2548445761203766)]
#
# Word: he
# Vector (first 5 dims shown): [ 0.01425471 -0.00312652  0.01594215 -0.01898413 -0.01596854] ...
# Top 5 similar words: [('final', 0.3512198328971863), ('send', 0.3374975621700287), ('tonight', 0.3037918508052826), ('miss', 0.29164695739746094), ('me', 0.2695235013961792)]
#
# Word: like
# Vector (first 5 dims shown): [-0.01063228 -0.0025437  -0.01470775  0.00389612  0.00656627] ...
# Top 5 similar words: [('breather', 0.410305380821228), ('times', 0.3572051525115967), ('yes', 0.3401658236980438), ('text', 0.3323832154273987), ('press', 0.3211105465888977)]
#
# Word: send
# Vector (first 5 dims shown): [0.01962127 0.01633298 0.00258013 0.01021192 0.00291446] ...
# Top 5 similar words: [('kl', 0.5276148319244385), ('great', 0.4124259352684021), ('he', 0.3374975621700287), ('got', 0.3036588728427887), ('already', 0.28268298506736755)]
#
# Word: fa
# Vector (first 5 dims shown): [ 0.00548407 -0.01069166  0.01331038  0.0090069  -0.01391792] ...
# Top 5 similar words: [('gota', 0.4596586525440216), ('use', 0.4226744771003723), ('here', 0.3978220224380493), ('ldnwarw', 0.38382434844970703), ('copy', 0.357084721326828)]
#
# Word: click
# Vector (first 5 dims shown): [-0.00375736 -0.01051417  0.01891191 -0.01865413  0.00918006] ...
# Top 5 similar words: [('treat', 0.37438905239105225), ('date', 0.3186917006969452), ('co', 0.2920699715614319), ('world', 0.2736158072948456), ('won', 0.27301985025405884)]
#
# Word: say
# Vector (first 5 dims shown): [ 0.01334887 -0.01365963  0.00196167 -0.01203012  0.00332736] ...
# Top 5 similar words: [('minnaminunginte', 0.36316564679145813), ('r', 0.3116981089115143), ('eh', 0.30094775557518005), ('has', 0.29729774594306946), ('valued', 0.29107868671417236)]
#
# Word: my
# Vector (first 5 dims shown): [-0.01895185  0.01913115 -0.01555648 -0.00530308 -0.00971292] ...
# Top 5 similar words: [('nurungu', 0.327363520860672), ('been', 0.31435057520866394), ('chgs', 0.29821276664733887), ('latest', 0.28625455498695374), ('more', 0.2709804177284241)]
#
# Word: promise
# Vector (first 5 dims shown): [-9.9723489e-05  1.7765790e-03 -1.4153425e-02  4.0977383e-03
#  -2.6761252e-03] ...
# Top 5 similar words: [('pounds', 0.36135366559028625), ('httpwap', 0.35331034660339355), ('overs', 0.3460861146450043), ('had', 0.32210472226142883), ('network', 0.31429362297058105)]
#
# Word: update
# Vector (first 5 dims shown): [ 0.01550844  0.01821785  0.00232161 -0.01670345  0.01693714] ...
# Top 5 similar words: [('valued', 0.3550325334072113), ('text', 0.33965829014778137), ('valid', 0.3093734085559845), ('txt', 0.27157267928123474), ('colour', 0.2694346606731415)]
#
# Word: me
# Vector (first 5 dims shown): [ 0.00666084  0.01023188  0.00923395 -0.0169548  -0.00628829] ...
# Top 5 similar words: [('word', 0.32562482357025146), ('pobox', 0.3048989772796631), ('b', 0.2917334735393524), ('aids', 0.2877717912197113), ('win', 0.2742636799812317)]
#
# Word: this
# Vector (first 5 dims shown): [-0.01431116  0.00842066  0.00437316  0.01492937 -0.00972237] ...
# Top 5 similar words: [('the', 0.37753820419311523), ('prize', 0.32594919204711914), ('fine', 0.3009418547153473), ('hours', 0.2952234148979187), ('k', 0.2879789173603058)]
#
# Word: apply
# Vector (first 5 dims shown): [-0.00969666 -0.00689598  0.01936662  0.0172644  -0.00553246] ...
# Top 5 similar words: [('did', 0.30133771896362305), ('words', 0.29306742548942566), ('searching', 0.2713882625102997), ('ive', 0.2685687839984894), ('crazy', 0.26114746928215027)]
#
# Word: will
# Vector (first 5 dims shown): [ 0.00273157 -0.01959762  0.00923058 -0.00113189  0.01290192] ...
# Top 5 similar words: [('hey', 0.4264147877693176), ('take', 0.3896607458591461), ('press', 0.3427658975124359), ('date', 0.33034414052963257), ('with', 0.32031163573265076)]
#
# Word: on
# Vector (first 5 dims shown): [-0.01040048 -0.01476872  0.0015141   0.00688175  0.0042243 ] ...
# Top 5 similar words: [('tkts', 0.406634658575058), ('wkly', 0.38762709498405457), ('tsandcs', 0.3241227865219116), ('tc', 0.29036223888397217), ('macedonia', 0.2886423170566559)]
#
# Word: win
# Vector (first 5 dims shown): [ 0.00369172  0.01410765  0.00597477 -0.01391539  0.01556969] ...
# Top 5 similar words: [('cost', 0.44897356629371643), ('name', 0.40304118394851685), ('oh', 0.3638724684715271), ('pobox', 0.3540709316730499), ('they', 0.34318307042121887)]
#
# Word: word
# Vector (first 5 dims shown): [ 0.01486199  0.01998431  0.0177745  -0.00802755  0.01939549] ...
# Top 5 similar words: [('if', 0.3996504843235016), ('feel', 0.3775511085987091), ('pobox', 0.3767172396183014), ('cup', 0.36043602228164673), ('b', 0.3595631718635559)]
#
# Word: its
# Vector (first 5 dims shown): [ 0.01951218 -0.01955056 -0.01292856  0.00552321  0.01302937] ...
# Top 5 similar words: [('pobox', 0.3669930398464203), ('lives', 0.3648865222930908), ('network', 0.3284362256526947), ('be', 0.31878337264060974), ('goes', 0.306696355342865)]
#
# Word: or
# Vector (first 5 dims shown): [-0.01023875 -0.01481352 -0.00577585 -0.00174571  0.00721927] ...
# Top 5 similar words: [('has', 0.36742573976516724), ('oru', 0.3583451211452484), ('jackpot', 0.3479902148246765), ('entitled', 0.2802139222621918), ('credit', 0.2801145017147064)]
#
# Word: until
# Vector (first 5 dims shown): [ 0.01129746  0.010952    0.00375978  0.01149826 -0.01788696] ...
# Top 5 similar words: [('here', 0.4313633441925049), ('hl', 0.3283054828643799), ('home', 0.32695674896240234), ('xxx', 0.3107077479362488), ('have', 0.29137176275253296)]
#
# Word: all
# Vector (first 5 dims shown): [-0.01874979 -0.00998002 -0.01947533 -0.01143032  0.00816348] ...
# Top 5 similar words: [('final', 0.34867003560066223), ('make', 0.2980315685272217), ('kl', 0.28698819875717163), ('will', 0.27295589447021484), ('darling', 0.2588023245334625)]
#
# Word: callertune
# Vector (first 5 dims shown): [ 0.00518977  0.00167181 -0.00508894  0.01868185  0.0056743 ] ...
# Top 5 similar words: [('pounds', 0.33339184522628784), ('still', 0.31994694471359253), ('eh', 0.31808218359947205), ('xxx', 0.2738508880138397), ('around', 0.25955015420913696)]
#
# Word: no
# Vector (first 5 dims shown): [ 0.01225781 -0.0135535   0.00142446 -0.00554993 -0.01033155] ...
# Top 5 similar words: [('kim', 0.3691467344760895), ('blessing', 0.36241477727890015), ('treat', 0.35368722677230835), ('copy', 0.3090512156486511), ('wet', 0.26630699634552)]
#
# Word: only
# Vector (first 5 dims shown): [ 0.00275489  0.01304703  0.02003803  0.01813741 -0.0159333 ] ...
# Top 5 similar words: [('not', 0.40510934591293335), ('scotland', 0.38441920280456543), ('trywales', 0.3329664468765259), ('membership', 0.3085838556289673), ('patent', 0.30841994285583496)]
#
# Word: england
# Vector (first 5 dims shown): [ 0.0133468   0.01201409 -0.01969521  0.00616196 -0.01183972] ...
# Top 5 similar words: [('pounds', 0.3004821538925171), ('gon', 0.27630019187927246), ('to', 0.2569023668766022), ('wif', 0.25655344128608704), ('you', 0.2553679943084717)]
#
# Word: prize
# Vector (first 5 dims shown): [-0.00038139  0.00844261  0.00425844  0.01995031  0.00128445] ...
# Top 5 similar words: [('this', 0.32594919204711914), ('kim', 0.30186185240745544), ('early', 0.2957778871059418), ('nah', 0.289407342672348), ('brother', 0.2890860438346863)]
#
# Word: way
# Vector (first 5 dims shown): [ 0.01889623 -0.00946913 -0.014461    0.01535901  0.00509531] ...
# Top 5 similar words: [('latest', 0.38050904870033264), ('spell', 0.3126140236854553), ('home', 0.30399927496910095), ('here', 0.28173714876174927), ('great', 0.2487117052078247)]
#
# Word: thats
# Vector (first 5 dims shown): [-0.00495518 -0.01171387  0.01506009 -0.01462623 -0.01774445] ...
# Top 5 similar words: [('wont', 0.41051897406578064), ('then', 0.37169477343559265), ('even', 0.33153966069221497), ('e', 0.30872899293899536), ('httpwap', 0.2734881043434143)]
#
# Word: ive
# Vector (first 5 dims shown): [ 0.00666603  0.00431091  0.01067598  0.01501365 -0.01170266] ...
# Top 5 similar words: [('tsandcs', 0.3580637574195862), ('entry', 0.2984258830547333), ('callers', 0.27752217650413513), ('pounds', 0.2712700366973877), ('did', 0.2707383334636688)]
#
# Word: call
# Vector (first 5 dims shown): [-0.00990987 -0.00258507  0.00659784 -0.01285969 -0.01934232] ...
# Top 5 similar words: [('already', 0.3771904408931732), ('wap', 0.3353916108608246), ('v', 0.32647231221199036), ('your', 0.32028594613075256), ('use', 0.2969364523887634)]
#
# Word: there
# Vector (first 5 dims shown): [0.01200016 0.01758511 0.00512084 0.00264019 0.01016865] ...
# Top 5 similar words: [('how', 0.33452969789505005), ('usf', 0.31372544169425964), ('week', 0.2978824973106384), ('ldnwarw', 0.29312968254089355), ('patent', 0.28943485021591187)]
#
# Word: melle
# Vector (first 5 dims shown): [ 0.01937463  0.01461355  0.00253375 -0.0068832  -0.00084584] ...
# Top 5 similar words: [('jackpot', 0.3743821978569031), ('latest', 0.34791386127471924), ('winner', 0.3241782784461975), ('his', 0.32269060611724854), ('urgent', 0.3047802150249481)]
#
# Word: ok
# Vector (first 5 dims shown): [-0.00472943 -0.00649773 -0.01629894 -0.00247766  0.00345619] ...
# Top 5 similar words: [('dont', 0.436854749917984), ('tb', 0.4308014512062073), ('remember', 0.3426809012889862), ('help', 0.3351043164730072), ('got', 0.31044963002204895)]
#
# Word: mobile
# Vector (first 5 dims shown): [-0.01383245 -0.0049705  -0.01601832  0.01499346  0.01238479] ...
# Top 5 similar words: [('yes', 0.4218052625656128), ('has', 0.3631327152252197), ('pounds', 0.32352301478385925), ('entry', 0.3066956400871277), ('more', 0.3052882254123688)]
#
# Word: entry
# Vector (first 5 dims shown): [ 0.00529723  0.00646017 -0.00049537  0.00341189 -0.00619775] ...
# Top 5 similar words: [('gon', 0.35736745595932007), ('usf', 0.3111822307109833), ('mobile', 0.30669569969177246), ('wif', 0.30386441946029663), ('pounds', 0.3021028935909271)]
#
# Word: still
# Vector (first 5 dims shown): [ 0.0042525   0.01146386 -0.0041812   0.00634472  0.01697743] ...
# Top 5 similar words: [('hor', 0.43210068345069885), ('joking', 0.38436639308929443), ('oh', 0.349926233291626), ('fun', 0.33815908432006836), ('callertune', 0.3199469745159149)]
#
# Word: it
# Vector (first 5 dims shown): [-0.00401691 -0.01956434  0.01047955 -0.01181927  0.00985716] ...
# Top 5 similar words: [('v', 0.38148000836372375), ('rcv', 0.37742939591407776), ('lccltd', 0.35705339908599854), ('national', 0.34624728560447693), ('jurong', 0.34039923548698425)]
#
# Word: some
# Vector (first 5 dims shown): [ 0.01674715 -0.0011328  -0.01885924  0.00952845 -0.01200069] ...
# Top 5 similar words: [('in', 0.3640008866786957), ('bugis', 0.35795167088508606), ('cup', 0.35103294253349304), ('want', 0.3336416482925415), ('cash', 0.32195544242858887)]
#
# Word: fun
# Vector (first 5 dims shown): [-1.9242514e-02  3.6092926e-05 -1.3705532e-02 -1.9058672e-03
#   6.1374470e-03] ...
# Top 5 similar words: [('still', 0.33815911412239075), ('even', 0.31966084241867065), ('wwwdbuknet', 0.30345419049263), ('fine', 0.2947952449321747), ('dun', 0.2898346483707428)]
#
# Word: tb
# Vector (first 5 dims shown): [-0.00853216 -0.01865436 -0.00370567 -0.00740936  0.01827266] ...
# Top 5 similar words: [('ok', 0.4308013916015625), ('blessing', 0.37030521035194397), ('watching', 0.3699333965778351), ('news', 0.3369061350822449), ('selected', 0.28065547347068787)]
#
# Word: xxx
# Vector (first 5 dims shown): [ 0.0055556   0.00208421 -0.01180625  0.01158938 -0.00495807] ...
# Top 5 similar words: [('kl', 0.339098185300827), ('minnaminunginte', 0.3216853141784668), ('won', 0.31255286931991577), ('until', 0.31070780754089355), ('text', 0.30244407057762146)]
#
# Word: up
# Vector (first 5 dims shown): [ 0.00042283  0.00428242  0.00218736  0.01517108 -0.00877502] ...
# Top 5 similar words: [('think', 0.3313828706741333), ('aids', 0.3025689721107483), ('fine', 0.2675231099128723), ('been', 0.26125848293304443), ('only', 0.25795456767082214)]
#
# Word: poboxoxwwq
# Vector (first 5 dims shown): [-0.00698081  0.00348841  0.00395157  0.01960243 -0.01117378] ...
# Top 5 similar words: [('bugis', 0.4033021330833435), ('wkly', 0.34027788043022156), ('have', 0.3132701516151428), ('as', 0.31046169996261597), ('though', 0.3041704595088959)]
#
# Word: std
# Vector (first 5 dims shown): [-0.00435344 -0.01941046  0.01863416  0.00407154 -0.00222505] ...
# Top 5 similar words: [('jackpot', 0.36889997124671936), ('press', 0.336614727973938), ('id', 0.32888585329055786), ('scotland', 0.288536936044693), ('national', 0.28646156191825867)]
#
# Word: patent
# Vector (first 5 dims shown): [ 0.01650651  0.01930186  0.01935742 -0.00769507 -0.01683852] ...
# Top 5 similar words: [('code', 0.339851051568985), ('message', 0.3106749951839447), ('only', 0.3084199130535126), ('there', 0.28943485021591187), ('home', 0.26420968770980835)]
#
# Word: set
# Vector (first 5 dims shown): [ 0.01286894 -0.01793547 -0.01469716 -0.00351229  0.00349149] ...
# Top 5 similar words: [('c', 0.34447115659713745), ('final', 0.3439057171344757), ('great', 0.32924434542655945), ('kl', 0.3269104063510895), ('back', 0.32097285985946655)]
#
# Word: has
# Vector (first 5 dims shown): [-0.00713703 -0.01391648  0.00156273  0.01548346  0.01832046] ...
# Top 5 similar words: [('more', 0.40988925099372864), ('v', 0.3728899359703064), ('or', 0.36742573976516724), ('camera', 0.3671204447746277), ('mobile', 0.3631327748298645)]
#
# Word: vettam
# Vector (first 5 dims shown): [ 0.00962278 -0.00731144 -0.00852915  0.00243259 -0.00818914] ...
# Top 5 similar words: [('want', 0.47658687829971313), ('amore', 0.38235917687416077), ('and', 0.3268219232559204), ('callers', 0.30571749806404114), ('set', 0.2970859110355377)]
#
# Word: nurungu
# Vector (first 5 dims shown): [-0.00294348  0.01917604 -0.01161363 -0.01410921  0.00479501] ...
# Top 5 similar words: [('be', 0.35853296518325806), ('spell', 0.3347117304801941), ('my', 0.3273634910583496), ('its', 0.28632211685180664), ('chances', 0.2730599045753479)]
#
# Word: minnaminunginte
# Vector (first 5 dims shown): [-0.00295123 -0.00811643 -0.00876461 -0.0093104  -0.01113379] ...
# Top 5 similar words: [('say', 0.36316564679145813), ('jurong', 0.3512713611125946), ('xxx', 0.3216853141784668), ('early', 0.2962423861026764), ('they', 0.2646435499191284)]
#
# Word: oru
# Vector (first 5 dims shown): [-0.01616424 -0.01360096  0.00242495 -0.00410028  0.01916583] ...
# Top 5 similar words: [('or', 0.3583451211452484), ('i', 0.34388768672943115), ('months', 0.31892478466033936), ('pday', 0.28712981939315796), ('stuff', 0.28201308846473694)]
#
# Word: request
# Vector (first 5 dims shown): [ 0.01593032 -0.01291504  0.0115881  -0.00047723 -0.01800356] ...
# Top 5 similar words: [('soon', 0.37468278408050537), ('macedonia', 0.31375038623809814), ('set', 0.2780792713165283), ('your', 0.2751392126083374), ('even', 0.257371187210083)]
#
# Word: per
# Vector (first 5 dims shown): [ 0.01007787  0.01806992 -0.01953485 -0.01837747  0.0198931 ] ...
# Top 5 similar words: [('valid', 0.3821921944618225), ('wif', 0.34068313241004944), ('available', 0.2984083592891693), ('won', 0.2955237627029419), ('wet', 0.28173646330833435)]
#
# Word: aids
# Vector (first 5 dims shown): [ 0.01080804  0.01965033 -0.01408305 -0.00124324 -0.01005405] ...
# Top 5 similar words: [('wap', 0.3350682854652405), ('up', 0.3025689125061035), ('some', 0.2892400920391083), ('me', 0.2877717912197113), ('b', 0.2539496421813965)]
#
# Word: chgs
# Vector (first 5 dims shown): [-0.0052644   0.00777751 -0.01216327 -0.01291226  0.00555759] ...
# Top 5 similar words: [('chances', 0.3408316969871521), ('b', 0.32851892709732056), ('searching', 0.32605186104774475), ('selected', 0.2993345558643341), ('my', 0.29821279644966125)]
#
# Word: treat
# Vector (first 5 dims shown): [ 0.00449256 -0.01502672  0.01130365 -0.01009111 -0.00646936] ...
# Top 5 similar words: [('here', 0.4482857584953308), ('click', 0.37438905239105225), ('date', 0.3608100414276123), ('no', 0.35368725657463074), ('hey', 0.34116578102111816)]
#
# Word: id
# Vector (first 5 dims shown): [-0.00015721 -0.00758111  0.00099633  0.00196461 -0.0187438 ] ...
# Top 5 similar words: [('free', 0.49181419610977173), ('gota', 0.38367190957069397), ('std', 0.32888588309288025), ('blessing', 0.32795706391334534), ('jackpot', 0.320004403591156)]
#
# Word: speak
# Vector (first 5 dims shown): [-0.01548978 -0.01352077 -0.00626964  0.01316908 -0.00154327] ...
# Top 5 similar words: [('if', 0.2916313111782074), ('like', 0.28902074694633484), ('pobox', 0.2865101397037506), ('st', 0.28323429822921753), ('jurong', 0.27787548303604126)]
#
# Word: not
# Vector (first 5 dims shown): [ 0.0115197   0.00575013  0.01366505 -0.00896988 -0.00625963] ...
# Top 5 similar words: [('co', 0.43037787079811096), ('only', 0.40510937571525574), ('bugis', 0.3204996883869171), ('receivea', 0.3085387349128723), ('right', 0.2954908311367035)]
#
# Word: is
# Vector (first 5 dims shown): [-0.00340938  0.01281366 -0.01852383 -0.01830902 -0.01029174] ...
# Top 5 similar words: [('selected', 0.3914777934551239), ('overs', 0.2961844205856323), ('wont', 0.26618674397468567), ('my', 0.25165310502052307), ('wat', 0.24849791824817657)]
#
# Word: brother
# Vector (first 5 dims shown): [-0.00939619  0.01739169  0.0151068   0.01844147  0.01879517] ...
# Top 5 similar words: [('dun', 0.37266436219215393), ('gon', 0.34425681829452515), ('camera', 0.33933913707733154), ('trywales', 0.3110143542289734), ('crazy', 0.3083442747592926)]
#
# Word: even
# Vector (first 5 dims shown): [-0.00954082 -0.00864476 -0.00959217 -0.01962217 -0.00150091] ...
# Top 5 similar words: [('thats', 0.3315396308898926), ('fun', 0.31966081261634827), ('date', 0.3143971860408783), ('make', 0.309637188911438), ('macedonia', 0.2573850154876709)]
#
# Word: rcv
# Vector (first 5 dims shown): [ 0.01009001 -0.00279388  0.00458113  0.00070398  0.01578339] ...
# Top 5 similar words: [('if', 0.3992392122745514), ('it', 0.37742936611175537), ('reply', 0.32211893796920776), ('gon', 0.27187415957450867), ('text', 0.266673743724823)]
#
# Word: they
# Vector (first 5 dims shown): [-0.01299941  0.01783734 -0.00314769 -0.01663305  0.01609756] ...
# Top 5 similar words: [('oh', 0.5625472664833069), ('at', 0.3768679201602936), ('for', 0.3702855110168457), ('weeks', 0.3531840443611145), ('win', 0.3431830406188965)]
#
# Word: usf
# Vector (first 5 dims shown): [ 0.00909665  0.00471781 -0.00571146  0.00126116 -0.01072454] ...
# Top 5 similar words: [('la', 0.4553339183330536), ('week', 0.3864670693874359), ('macedonia', 0.3296603858470917), ('xxxmobilemovieclub', 0.3192123472690582), ('there', 0.31372547149658203)]
#
# Word: back
# Vector (first 5 dims shown): [ 0.01030524 -0.00883553 -0.0183245  -0.01815616  0.01255595] ...
# Top 5 similar words: [('set', 0.3209728002548218), ('goes', 0.2864551544189453), ('trywales', 0.2746194005012512), ('granted', 0.2706989049911499), ('c', 0.2493707537651062)]
#
# Word: now
# Vector (first 5 dims shown): [ 0.00022272  0.01007819  0.00445219  0.01765064 -0.01656431] ...
# Top 5 similar words: [('comp', 0.38658246397972107), ('poboxoxwwq', 0.2958837151527405), ('anymore', 0.2870267629623413), ('from', 0.2811955213546753), ('csh', 0.2774930000305176)]
#
# Word: final
# Vector (first 5 dims shown): [-0.0051533  -0.01584445 -0.01645344 -0.01515867  0.00720934] ...
# Top 5 similar words: [('kl', 0.38401398062705994), ('he', 0.3512198030948639), ('all', 0.34867000579833984), ('available', 0.3447611629962921), ('set', 0.3439057171344757)]
#
# Word: cup
# Vector (first 5 dims shown): [0.00784497 0.00340724 0.00580756 0.01630105 0.01346769] ...
# Top 5 similar words: [('pobox', 0.4561421871185303), ('word', 0.3604361116886139), ('some', 0.35103294253349304), ('eh', 0.3503448963165283), ('ur', 0.29158157110214233)]
#
# Word: comp
# Vector (first 5 dims shown): [-0.01639457  0.00035416  0.01213346  0.01915326 -0.00561546] ...
# Top 5 similar words: [('at', 0.42298704385757446), ('had', 0.41365882754325867), ('use', 0.4094601571559906), ('now', 0.38658252358436584), ('ratetcs', 0.37222981452941895)]
#
# Word: wkly
# Vector (first 5 dims shown): [-0.01173247 -0.00556439 -0.01724466 -0.00695411 -0.00506929] ...
# Top 5 similar words: [('on', 0.3876270353794098), ('overs', 0.3557891547679901), ('poboxoxwwq', 0.34027785062789917), ('cine', 0.3184901475906372), ('id', 0.3091781437397003)]
#
# Word: oni
# Vector (first 5 dims shown): [ 0.01605771  0.01584581 -0.0108044  -0.01596255  0.01622885] ...
# Top 5 similar words: [('reply', 0.3695144057273865), ('selected', 0.3467453122138977), ('txt', 0.33109402656555176), ('entitled', 0.2829151749610901), ('tsandcs', 0.24286000430583954)]
#
# Word: wif
# Vector (first 5 dims shown): [ 0.00040499 -0.01602164 -0.0132594  -0.01892235  0.01075927] ...
# Top 5 similar words: [('csh', 0.45881175994873047), ('pday', 0.3722003698348999), ('per', 0.3406831622123718), ('customer', 0.33584001660346985), ('how', 0.3061889708042145)]
#
# Word: joking
# Vector (first 5 dims shown): [-0.01225677  0.00938025 -0.01810748  0.0101666   0.01275641] ...
# Top 5 similar words: [('still', 0.38436636328697205), ('ratetcs', 0.37416335940361023), ('for', 0.3562956154346466), ('days', 0.2744644284248352), ('fun', 0.26581010222435)]
#
# Word: lar
# Vector (first 5 dims shown): [ 0.0044841  -0.00542057  0.00820816  0.01218363  0.01798205] ...
# Top 5 similar words: [('message', 0.3569414019584656), ('k', 0.34853658080101013), ('mobiles', 0.32025179266929626), ('name', 0.30759066343307495), ('though', 0.30011796951293945)]
#
# Word: wat
# Vector (first 5 dims shown): [-0.00541092  0.00022661  0.00405373 -0.01859816  0.00976818] ...
# Top 5 similar words: [('lives', 0.44089236855506897), ('anymore', 0.35844260454177856), ('win', 0.3370133340358734), ('weeks', 0.3298087418079376), ('around', 0.32499411702156067)]
#
# Word: amore
# Vector (first 5 dims shown): [ 0.00881305  0.00047219 -0.00974831  0.00725417  0.00344303] ...
# Top 5 similar words: [('vettam', 0.38235923647880554), ('reward', 0.3254169225692749), ('xxxmobilemovieclubcomnqjkgighjjgcbl', 0.3072224259376526), ('macedonia', 0.2974700927734375), ('free', 0.2860356271266937)]
#
# Word: got
# Vector (first 5 dims shown): [ 0.00139869  0.01297573  0.01173891 -0.00037681  0.00482945] ...
# Top 5 similar words: [('today', 0.35842493176460266), ('more', 0.33561578392982483), ('ok', 0.3104496896266937), ('httpwap', 0.30762046575546265), ('send', 0.3036588430404663)]
#
# Word: cine
# Vector (first 5 dims shown): [-0.0049433  -0.00565854 -0.0176956  -0.01156856  0.01896566] ...
# Top 5 similar words: [('goes', 0.3622703552246094), ('wkly', 0.3184901475906372), ('wif', 0.2961859107017517), ('hours', 0.2753557562828064), ('receive', 0.25786250829696655)]
#
# Word: buffet
# Vector (first 5 dims shown): [-0.0022674  -0.00473335 -0.00362277 -0.00235865 -0.0129626 ] ...
# Top 5 similar words: [('date', 0.28581082820892334), ('code', 0.275554358959198), ('tkts', 0.2711683511734009), ('wont', 0.2692965865135193), ('chances', 0.2679348289966583)]
#
# Word: e
# Vector (first 5 dims shown): [ 0.0179889  -0.00384566 -0.0031869  -0.00597076  0.00110798] ...
# Top 5 similar words: [('ur', 0.33392736315727234), ('thats', 0.30872899293899536), ('xxxmobilemovieclub', 0.30368897318840027), ('watching', 0.294280081987381), ('then', 0.2900781035423279)]
#
# Word: la
# Vector (first 5 dims shown): [ 0.00948465 -0.01813741 -0.01847838  0.00198502 -0.01708084] ...
# Top 5 similar words: [('pounds', 0.4601178467273712), ('usf', 0.45533397793769836), ('want', 0.35492995381355286), ('jackpot', 0.29931899905204773), ('receive', 0.2867804169654846)]
#
# Word: world
# Vector (first 5 dims shown): [-0.01688638 -0.00776139  0.01756568 -0.01901022  0.01974615] ...
# Top 5 similar words: [('oh', 0.4049149453639984), ('right', 0.38763660192489624), ('naughty', 0.35407140851020813), ('week', 0.34528475999832153), ('news', 0.3385457396507263)]
#
# Word: great
# Vector (first 5 dims shown): [ 0.01994583  0.0048176   0.01025044 -0.0113496   0.00882538] ...
# Top 5 similar words: [('send', 0.4124259352684021), ('name', 0.3837894797325134), ('set', 0.32924431562423706), ('win', 0.324250191450119), ('lar', 0.295174241065979)]
#
# Word: n
# Vector (first 5 dims shown): [ 0.00374514  0.00926944 -0.01252083  0.01047791 -0.00701428] ...
# Top 5 similar words: [('wap', 0.33845055103302), ('days', 0.30343347787857056), ('tsandcs', 0.29667961597442627), ('xxx', 0.2889808714389801), ('home', 0.27650001645088196)]
#
# Word: bugis
# Vector (first 5 dims shown): [ 0.01402657 -0.00043376 -0.01587022  0.01778128 -0.01704577] ...
# Top 5 similar words: [('poboxoxwwq', 0.4033021926879883), ('feel', 0.35857129096984863), ('some', 0.35795167088508606), ('cash', 0.32663917541503906), ('not', 0.3204996883869171)]
#
# Word: available
# Vector (first 5 dims shown): [ 0.01464757 -0.01854713 -0.01724968 -0.01962087  0.0184502 ] ...
# Top 5 similar words: [('final', 0.3447611927986145), ('want', 0.32673051953315735), ('been', 0.3132782578468323), ('treat', 0.3010846674442291), ('ur', 0.2987078130245209)]
#
# Word: crazy
# Vector (first 5 dims shown): [-0.00663549 -0.01380214  0.01302541  0.01878443  0.01661052] ...
# Top 5 similar words: [('reward', 0.4475535452365875), ('dont', 0.4195510745048523), ('hours', 0.36559003591537476), ('remember', 0.3341420888900757), ('as', 0.3147205710411072)]
#
# Word: point
# Vector (first 5 dims shown): [-0.00670413  0.00072289  0.01220932  0.00955673 -0.01188049] ...
# Top 5 similar words: [('hl', 0.40925824642181396), ('info', 0.3248929977416992), ('xxxmobilemovieclub', 0.28163865208625793), ('his', 0.2729082405567169), ('speak', 0.2694496512413025)]
#
# Word: jurong
# Vector (first 5 dims shown): [-0.01568008 -0.01668878  0.00231869 -0.00152648 -0.01899927] ...
# Top 5 similar words: [('lccltd', 0.38144171237945557), ('minnaminunginte', 0.3512713611125946), ('it', 0.34039920568466187), ('v', 0.33911290764808655), ('next', 0.3160485625267029)]
#
# Word: tkts
# Vector (first 5 dims shown): [ 0.01978312 -0.01647361 -0.00335443  0.01259125 -0.01834433] ...
# Top 5 similar words: [('on', 0.4066345989704132), ('im', 0.30044564604759216), ('around', 0.27980899810791016), ('message', 0.27621689438819885), ('great', 0.27361854910850525)]
#
# Word: st
# Vector (first 5 dims shown): [-0.00475068  0.01506797  0.00415472  0.00584961 -0.00238793] ...
# Top 5 similar words: [('if', 0.4516385793685913), ('win', 0.3255465626716614), ('cried', 0.3080819845199585), ('talk', 0.29687461256980896), ('usf', 0.2966110110282898)]
#
# Word: may
# Vector (first 5 dims shown): [-0.01625024 -0.01063101  0.01209911 -0.01531462  0.01739865] ...
# Top 5 similar words: [('team', 0.33658936619758606), ('how', 0.290720671415329), ('make', 0.28309768438339233), ('watching', 0.27278417348861694), ('remember', 0.2692815363407135)]
#
# Word: nah
# Vector (first 5 dims shown): [ 0.01999727  0.00111451 -0.01025537 -0.00729517  0.00258118] ...
# Top 5 similar words: [('won', 0.3628142178058624), ('wap', 0.29427704215049744), ('prize', 0.2894073724746704), ('copy', 0.282681405544281), ('winner', 0.2516050636768341)]
#
# Word: weeks
# Vector (first 5 dims shown): [ 0.00753927  0.0069577   0.00670344 -0.01123436  0.01605481] ...
# Top 5 similar words: [('remember', 0.45738837122917175), ('eg', 0.3771395981311798), ('im', 0.37711450457572937), ('r', 0.35343247652053833), ('they', 0.3531840145587921)]
#
# Word: darling
# Vector (first 5 dims shown): [-0.01290165  0.01469141  0.01229571 -0.00984684 -0.00343744] ...
# Top 5 similar words: [('dun', 0.3953031897544861), ('naughty', 0.37026548385620117), ('ur', 0.3621315658092499), ('be', 0.3358772099018097), ('you', 0.3185362219810486)]
#
# Word: hey
# Vector (first 5 dims shown): [-0.00853938 -0.0194752   0.01367176 -0.00906601  0.0089216 ] ...
# Top 5 similar words: [('will', 0.42641481757164), ('reward', 0.34207919239997864), ('treat', 0.34116581082344055), ('words', 0.3033447563648224), ('copy', 0.3031342327594757)]
#
# Word: freemsg
# Vector (first 5 dims shown): [ 0.0022849   0.01235926 -0.0131452   0.01308519  0.01968616] ...
# Top 5 similar words: [('did', 0.40061309933662415), ('lar', 0.29116755723953247), ('for', 0.2871098220348358), ('great', 0.2803178131580353), ('per', 0.2791445851325989)]
#
# Word: though
# Vector (first 5 dims shown): [ 0.01844702 -0.0114149   0.00653945 -0.01564882 -0.01779255] ...
# Top 5 similar words: [('our', 0.4945025146007538), ('copy', 0.3159506022930145), ('thank', 0.3056783676147461), ('gota', 0.30460652709007263), ('poboxoxwwq', 0.3041704297065735)]
#
# Word: around
# Vector (first 5 dims shown): [-0.00168159 -0.01048205  0.01827332  0.00678805  0.00864053] ...
# Top 5 similar words: [('receivea', 0.4578150510787964), ('fine', 0.3442305624485016), ('wat', 0.3249940872192383), ('win', 0.30982816219329834), ('hours', 0.30384719371795654)]
#
# Word: lives
# Vector (first 5 dims shown): [-0.01877102 -0.00649839 -0.00083791 -0.00970771  0.01900734] ...
# Top 5 similar words: [('wat', 0.4408922791481018), ('questionstd', 0.367866575717926), ('its', 0.3648865222930908), ('has', 0.3546809256076813), ('oh', 0.3130764365196228)]
#
# Word: press
# Vector (first 5 dims shown): [ 0.0052473  -0.01538283  0.01139933  0.01512347 -0.0050414 ] ...
# Top 5 similar words: [('will', 0.34276583790779114), ('link', 0.33768364787101746), ('std', 0.3366146981716156), ('like', 0.3211105763912201), ('im', 0.31537970900535583)]
#
# Word: goes
# Vector (first 5 dims shown): [ 0.01979122  0.0127924  -0.00993408 -0.01216346  0.01455981] ...
# Top 5 similar words: [('receive', 0.4077700972557068), ('months', 0.4059678316116333), ('cine', 0.3622703552246094), ('had', 0.3319840431213379), ('its', 0.306696355342865)]
#
# Word: think
# Vector (first 5 dims shown): [ 0.01962655  0.00837259 -0.00423832 -0.00993716 -0.01938462] ...
# Top 5 similar words: [('up', 0.3313829004764557), ('winner', 0.3118857443332672), ('latest', 0.2921147346496582), ('from', 0.27642181515693665), ('pounds', 0.2592394948005676)]
#
# Word: then
# Vector (first 5 dims shown): [-0.00851293 -0.01278658  0.00798543 -0.00587937 -0.01425639] ...
# Top 5 similar words: [('thats', 0.37169477343559265), ('jackpot', 0.2984093129634857), ('e', 0.2900780737400055), ('world', 0.2850929796695709), ('has', 0.2848653793334961)]
#
# Word: text
# Vector (first 5 dims shown): [ 0.00853929  0.00077287 -0.00175329 -0.00647274  0.01004633] ...
# Top 5 similar words: [('fine', 0.40300101041793823), ('httpwap', 0.36313408613204956), ('yes', 0.34321075677871704), ('update', 0.339658260345459), ('link', 0.3391399681568146)]
#
# Word: already
# Vector (first 5 dims shown): [-0.01118728  0.01424957  0.01494304 -0.0179412  -0.01068404] ...
# Top 5 similar words: [('txt', 0.38812899589538574), ('call', 0.37719038128852844), ('id', 0.30464425683021545), ('sunday', 0.2990238070487976), ('credit', 0.2859978675842285)]
#
# Word: c
# Vector (first 5 dims shown): [ 0.00406881  0.01650745 -0.01655644 -0.01751901 -0.00101566] ...
# Top 5 similar words: [('did', 0.3567482829093933), ('set', 0.34447115659713745), ('and', 0.2860781252384186), ('win', 0.276637464761734), ('update', 0.2575176954269409)]
#
# Word: hor
# Vector (first 5 dims shown): [-0.0121784   0.00646055 -0.00856127  0.01763697  0.00834923] ...
# Top 5 similar words: [('still', 0.43210071325302124), ('help', 0.2765105366706848), ('n', 0.26942840218544006), ('name', 0.25137537717819214), ('six', 0.25047507882118225)]
#
# Word: early
# Vector (first 5 dims shown): [-0.00013789 -0.01987753 -0.01499974  0.01710057  0.0038628 ] ...
# Top 5 similar words: [('help', 0.32928645610809326), ('treat', 0.31473231315612793), ('anymore', 0.30487653613090515), ('minnaminunginte', 0.2962423861026764), ('prize', 0.29577791690826416)]
#
# Word: so
# Vector (first 5 dims shown): [ 0.0125648  -0.01553169  0.01647996 -0.01973193 -0.01476717] ...
# Top 5 similar words: [('national', 0.38558268547058105), ('ldnwarw', 0.327831894159317), ('with', 0.28189578652381897), ('na', 0.27085891366004944), ('entitled', 0.26842331886291504)]
#
# Word: dun
# Vector (first 5 dims shown): [-0.01609816 -0.00178461  0.01282406  0.01747285 -0.0099968 ] ...
# Top 5 similar words: [('darling', 0.39530321955680847), ('brother', 0.3726644217967987), ('to', 0.32582640647888184), ('comp', 0.3210203945636749), ('you', 0.3012385368347168)]
#
# Word: overs
# Vector (first 5 dims shown): [-0.0071467   0.00722824 -0.00511175 -0.00946113 -0.00716499] ...
# Top 5 similar words: [('wkly', 0.3557891249656677), ('promise', 0.3460860848426819), ('is', 0.29618439078330994), ('you', 0.2959080636501312), ('some', 0.27822381258010864)]
#
# Word: ratetcs
# Vector (first 5 dims shown): [-0.01688462  0.01294631 -0.01152661 -0.00350766  0.00203211] ...
# Top 5 similar words: [('team', 0.39532676339149475), ('joking', 0.37416332960128784), ('comp', 0.3722297251224518), ('help', 0.31782010197639465), ('home', 0.31684428453445435)]
#
# Word: questionstd
# Vector (first 5 dims shown): [-0.00825478  0.000496    0.00142891  0.0152393   0.01373949] ...
# Top 5 similar words: [('mobiles', 0.38926783204078674), ('lives', 0.3678666055202484), ('has', 0.3545753061771393), ('you', 0.3338215947151184), ('wont', 0.3021010458469391)]
#
# Word: receive
# Vector (first 5 dims shown): [ 0.01724851 -0.01172885 -0.01515535 -0.00279974  0.0060342 ] ...
# Top 5 similar words: [('feel', 0.4746015667915344), ('goes', 0.40777015686035156), ('urgent', 0.3881765305995941), ('la', 0.286780446767807), ('e', 0.2813256084918976)]
#
# Word: callers
# Vector (first 5 dims shown): [ 0.00790652 -0.00991498  0.01277574  0.01316825 -0.01744968] ...
# Top 5 similar words: [('latest', 0.38050153851509094), ('vettam', 0.30571746826171875), ('wwwdbuknet', 0.29461270570755005), ('u', 0.29314056038856506), ('ive', 0.27752217650413513)]
#
# Word: receivea
# Vector (first 5 dims shown): [-0.00443657  0.00381392  0.01562239 -0.01126829  0.00765927] ...
# Top 5 similar words: [('around', 0.4578150510787964), ('for', 0.40354618430137634), ('fulfil', 0.32203036546707153), ('not', 0.3085387349128723), ('valued', 0.29852816462516785)]
#
# Word: copy
# Vector (first 5 dims shown): [ 0.01914083 -0.01819952  0.01442961 -0.01517141 -0.00064436] ...
# Top 5 similar words: [('sunday', 0.4028555750846863), ('here', 0.3809436857700348), ('fa', 0.35708481073379517), ('your', 0.35183921456336975), ('though', 0.3159506320953369)]
#
# Word: blessing
# Vector (first 5 dims shown): [ 0.00621867 -0.00316666 -0.0023725  -0.01172303 -0.01147625] ...
# Top 5 similar words: [('tb', 0.37030524015426636), ('no', 0.36241474747657776), ('id', 0.3279570937156677), ('fa', 0.3241003155708313), ('melle', 0.2708485424518585)]
#
# Word: httpwap
# Vector (first 5 dims shown): [-0.00664289  0.00054387  0.00755066 -0.00569182 -0.00874418] ...
# Top 5 similar words: [('text', 0.3631341755390167), ('promise', 0.35331034660339355), ('i', 0.33819687366485596), ('chances', 0.3204798400402069), ('mobiles', 0.3181004822254181)]
#
# Word: message
# Vector (first 5 dims shown): [0.00478154 0.00855476 0.0039474  0.01623784 0.01785456] ...
# Top 5 similar words: [('lar', 0.3569413721561432), ('urgent', 0.3412565290927887), ('patent', 0.3106749653816223), ('freemsg', 0.2785767912864685), ('name', 0.2765619158744812)]
#
# Word: next
# Vector (first 5 dims shown): [ 0.01028097  0.01983323 -0.01128841  0.00168623  0.00877753] ...
# Top 5 similar words: [('did', 0.3582358956336975), ('a', 0.3530220687389374), ('credit', 0.3294943869113922), ('valid', 0.31651604175567627), ('jurong', 0.3160485327243805)]
#
# Word: link
# Vector (first 5 dims shown): [ 0.00850401  0.00478064 -0.00081526 -0.00122942  0.00538017] ...
# Top 5 similar words: [('soon', 0.4110743999481201), ('take', 0.3789482116699219), ('b', 0.36006754636764526), ('text', 0.33914002776145935), ('press', 0.33768364787101746)]
#
# Word: wap
# Vector (first 5 dims shown): [-0.00069983  0.01956862 -0.01021229  0.00815405 -0.01138087] ...
# Top 5 similar words: [('remember', 0.3669262230396271), ('n', 0.33845052123069763), ('call', 0.335391640663147), ('aids', 0.33506831526756287), ('home', 0.32476288080215454)]
#
# Word: credit
# Vector (first 5 dims shown): [-0.01477709  0.0132515  -0.00674759 -0.00185867  0.01086065] ...
# Top 5 similar words: [('pobox', 0.4164332449436188), ('next', 0.3294943869113922), ('to', 0.32306137681007385), ('txt', 0.3007228672504425), ('valid', 0.2986648380756378)]
#
# Word: use
# Vector (first 5 dims shown): [-5.7763484e-04  1.2683934e-02 -7.6898593e-03  9.1613261e-03
#  -3.4814202e-05] ...
# Top 5 similar words: [('fa', 0.4226745665073395), ('comp', 0.4094601571559906), ('months', 0.38507771492004395), ('ldnwarw', 0.3551238179206848), ('urgent', 0.34810671210289)]
#
# Word: xxxmobilemovieclub
# Vector (first 5 dims shown): [-0.00117192  0.00283798 -0.00237913 -0.00810835  0.00182699] ...
# Top 5 similar words: [('and', 0.37689611315727234), ('tonight', 0.36750903725624084), ('wet', 0.32819071412086487), ('feel', 0.32454386353492737), ('macedonia', 0.3217408359050751)]
#
# Word: sunday
# Vector (first 5 dims shown): [-0.00023663 -0.0121302  -0.00721003 -0.00328765 -0.0198775 ] ...
# Top 5 similar words: [('copy', 0.4028555452823639), ('already', 0.2990238666534424), ('id', 0.28156062960624695), ('how', 0.27643877267837524), ('comp', 0.266430526971817)]
#
# Word: date
# Vector (first 5 dims shown): [ 0.00623479 -0.01969127  0.00646784 -0.00899845  0.01940787] ...
# Top 5 similar words: [('make', 0.4062638282775879), ('treat', 0.36080998182296753), ('won', 0.3572172224521637), ('will', 0.3303441107273102), ('click', 0.3186917304992676)]
#
# Word: times
# Vector (first 5 dims shown): [-0.01092215 -0.00241912 -0.01108428  0.01699491  0.01825984] ...
# Top 5 similar words: [('like', 0.3572051525115967), ('want', 0.32821834087371826), ('friends', 0.2547746002674103), ('around', 0.2545017600059509), ('week', 0.24808654189109802)]
#
# Word: at
# Vector (first 5 dims shown): [-0.01429669  0.0126558  -0.00392495 -0.00954412  0.00996852] ...
# Top 5 similar words: [('comp', 0.42298704385757446), ('they', 0.37686794996261597), ('had', 0.3602253198623657), ('a', 0.3031574785709381), ('ratetcs', 0.29407790303230286)]
#
# Word: wonderful
# Vector (first 5 dims shown): [-0.01585062  0.01073733 -0.00843118  0.00075094  0.0157178 ] ...
# Top 5 similar words: [('six', 0.3195081949234009), ('u', 0.2773377299308777), ('and', 0.27333712577819824), ('trywales', 0.2598304748535156), ('jackpot', 0.24307839572429657)]
#
# Word: wwwdbuknet
# Vector (first 5 dims shown): [-0.01388526  0.01806002  0.01289026 -0.00825831 -0.00609161] ...
# Top 5 similar words: [('chances', 0.46312424540519714), ('with', 0.44632935523986816), ('naughty', 0.3713587820529938), ('if', 0.33682137727737427), ('fun', 0.30345419049263)]
#
# Word: fulfil
# Vector (first 5 dims shown): [-0.019023    0.01626441  0.01123184 -0.01652886  0.01147886] ...
# Top 5 similar words: [('cost', 0.33785480260849), ('receivea', 0.3220303952693939), ('right', 0.31203871965408325), ('darling', 0.31024497747421265), ('gon', 0.28533297777175903)]
#
# Word: granted
# Vector (first 5 dims shown): [ 0.00198691  0.01715604 -0.00797848  0.00594499  0.00649765] ...
# Top 5 similar words: [('membership', 0.37002870440483093), ('team', 0.30161166191101074), ('in', 0.29640212655067444), ('call', 0.28509321808815), ('back', 0.2706989645957947)]
#
# Word: help
# Vector (first 5 dims shown): [-0.01814665  0.0100652  -0.00632603  0.01918844  0.00831968] ...
# Top 5 similar words: [('news', 0.40529245138168335), ('i', 0.3552585542201996), ('ok', 0.3351043164730072), ('early', 0.32928645610809326), ('ratetcs', 0.31782016158103943)]
#
# Word: take
# Vector (first 5 dims shown): [ 0.01091359  0.01366597  0.01222342 -0.01906887  0.01938696] ...
# Top 5 similar words: [('v', 0.42954832315444946), ('will', 0.38966071605682373), ('won', 0.3889800012111664), ('link', 0.3789482116699219), ('gota', 0.3432883620262146)]
#
# Word: wont
# Vector (first 5 dims shown): [ 0.01023516 -0.01744684  0.00517562  0.01653322 -0.00452193] ...
# Top 5 similar words: [('thats', 0.41051897406578064), ('mobiles', 0.36697301268577576), ('selected', 0.31471145153045654), ('news', 0.30980730056762695), ('questionstd', 0.3021010160446167)]
#
# Word: breather
# Vector (first 5 dims shown): [-0.00442019  0.01500324 -0.00615299  0.0070878   0.00032235] ...
# Top 5 similar words: [('like', 0.41030535101890564), ('enough', 0.3564172685146332), ('trywales', 0.33022886514663696), ('tonight', 0.3223940134048462), ('feel', 0.2960902452468872)]
#
# Word: thank
# Vector (first 5 dims shown): [ 0.01228882 -0.00390461  0.01318194 -0.00556527 -0.00155643] ...
# Top 5 similar words: [('hl', 0.3749498724937439), ('promise', 0.30768710374832153), ('though', 0.3056783676147461), ('darling', 0.3014487624168396), ('copy', 0.290473610162735)]
#
# Word: words
# Vector (first 5 dims shown): [0.01201587 0.00754259 0.00355492 0.0012825  0.01774192] ...
# Top 5 similar words: [('co', 0.3592219054698944), ('if', 0.324521541595459), ('hey', 0.3033447265625), ('apply', 0.29306745529174805), ('wwwdbuknet', 0.2879939377307892)]
#
# Word: right
# Vector (first 5 dims shown): [-0.00103857 -0.01412988  0.01999453 -0.0132563   0.01381231] ...
# Top 5 similar words: [('world', 0.38763660192489624), ('fulfil', 0.31203874945640564), ('national', 0.2996423542499542), ('not', 0.2954908311367035), ('scotland', 0.2862411141395569)]
#
# Word: searching
# Vector (first 5 dims shown): [-0.01974654 -0.00085524 -0.00937022 -0.00842161 -0.00357094] ...
# Top 5 similar words: [('chances', 0.38656705617904663), ('chgs', 0.32605186104774475), ('cried', 0.3136683404445648), ('selected', 0.3017491400241852), ('wwwdbuknet', 0.2808806002140045)]
#
# Word: ldnwarw
# Vector (first 5 dims shown): [ 0.00062246  0.00304052  0.00404119 -0.00347018 -0.00518085] ...
# Top 5 similar words: [('months', 0.39520716667175293), ('fa', 0.3838243782520294), ('v', 0.3601140081882477), ('use', 0.3551238477230072), ('treat', 0.33550968766212463)]
#
# Word: pobox
# Vector (first 5 dims shown): [ 0.01010188 -0.00733441  0.00690788  0.00160173  0.01813269] ...
# Top 5 similar words: [('cup', 0.45614221692085266), ('credit', 0.41643327474594116), ('word', 0.3767172396183014), ('its', 0.3669930100440979), ('win', 0.35407090187072754)]
#
# Word: xxxmobilemovieclubcomnqjkgighjjgcbl
# Vector (first 5 dims shown): [ 0.00753139  0.0149627  -0.00040932  0.00787517 -0.01323034] ...
# Top 5 similar words: [('macedonia', 0.4544481337070465), ('claim', 0.3529072701931), ('amore', 0.3072223961353302), ('info', 0.2896503806114197), ('questionstd', 0.28666314482688904)]
#
# Word: oh
# Vector (first 5 dims shown): [-0.01789198  0.01071834  0.00754218 -0.01215682  0.01222283] ...
# Top 5 similar words: [('they', 0.5625472664833069), ('world', 0.4049149751663208), ('cost', 0.39911162853240967), ('news', 0.37427130341529846), ('win', 0.3638724982738495)]
#
# Word: kim
# Vector (first 5 dims shown): [ 0.0186637  -0.01570697  0.01065583  0.01108619 -0.00991304] ...
# Top 5 similar words: [('eg', 0.3947528004646301), ('no', 0.3691467046737671), ('mobiles', 0.3163478672504425), ('prize', 0.30186188220977783), ('wet', 0.27470269799232483)]
#
# Word: watching
# Vector (first 5 dims shown): [0.00851084 0.00041521 0.00965204 0.0058609  0.00299031] ...
# ...
# Top 5 similar words: [('until', 0.32695671916007996), ('wap', 0.32476285099983215), ('ratetcs', 0.31684422492980957), ('days', 0.31336405873298645), ('latest', 0.31217148900032043)]
#
# Word: be
# Vector (first 5 dims shown): [ 0.01756166  0.00945955  0.00847383 -0.01171062  0.015525  ] ...
# Top 5 similar words: [('valued', 0.47621989250183105), ('nurungu', 0.35853299498558044), ('spell', 0.3382261395454407), ('darling', 0.33587726950645447), ('colour', 0.3219982385635376)]
#
# Word: na
# Vector (first 5 dims shown): [ 0.0067372  -0.0183698   0.00924361  0.00932057 -0.01552647] ...
# Top 5 similar words: [('had', 0.3041919469833374), ('im', 0.2850763499736786), ('so', 0.2708589732646942), ('sunday', 0.2660312056541443), ('got', 0.2624940872192383)]
#
# Word: gon
# Vector (first 5 dims shown): [-0.01147595  0.01467024  0.01415217 -0.0176212   0.00625978] ...
# Top 5 similar words: [('from', 0.36219555139541626), ('entry', 0.35736745595932007), ('brother', 0.34425684809684753), ('darling', 0.2951001822948456), ('fulfil', 0.2853330075740814)]
#
# Word: im
# Vector (first 5 dims shown): [ 0.01211353 -0.01124547  0.01581662  0.013479   -0.01399958] ...
# Top 5 similar words: [('r', 0.381146103143692), ('weeks', 0.37711450457572937), ('go', 0.32856568694114685), ('press', 0.3153797388076782), ('tkts', 0.30044564604759216)]
#
# Word: co
# Vector (first 5 dims shown): [-0.00587706  0.00569503  0.0119565  -0.00813918 -0.00570986] ...
# Top 5 similar words: [('not', 0.4303778409957886), ('words', 0.359221875667572), ('six', 0.3450435698032379), ('click', 0.2920700013637543), ('r', 0.2815649211406708)]
#
# Word: camera
# Vector (first 5 dims shown): [-0.00105812  0.00800361  0.00610113  0.01332513  0.01967634] ...
# Top 5 similar words: [('has', 0.3671204447746277), ('brother', 0.33933916687965393), ('want', 0.3102898895740509), ('i', 0.30026543140411377), ('words', 0.26518431305885315)]
#
# Word: mobiles
# Vector (first 5 dims shown): [ 0.00375256 -0.00094095  0.00580149  0.01793992 -0.00033678] ...
# Top 5 similar words: [('cried', 0.41695138812065125), ('questionstd', 0.38926783204078674), ('wont', 0.36697301268577576), ('lar', 0.3202517628669739), ('httpwap', 0.31810054183006287)]
#
# Word: colour
# Vector (first 5 dims shown): [ 0.01240271 -0.00405547  0.01256756  0.0030686   0.00889972] ...
# Top 5 similar words: [('be', 0.3219982087612152), ('today', 0.31669506430625916), ('overs', 0.2751758098602295), ('update', 0.26943469047546387), ('e', 0.2543937861919403)]
#
# Word: latest
# Vector (first 5 dims shown): [ 0.01871032  0.00940819 -0.00714045 -0.00758153 -0.01702071] ...
# Top 5 similar words: [('way', 0.38050904870033264), ('callers', 0.38050150871276855), ('days', 0.3767296373844147), ('melle', 0.34791386127471924), ('spell', 0.3301982283592224)]
#
# Word: entitled
# Vector (first 5 dims shown): [ 0.00882141  0.01377598  0.00184597 -0.01171661  0.00914927] ...
# Top 5 similar words: [('at', 0.2928221523761749), ('oni', 0.2829152047634125), ('i', 0.2815214693546295), ('or', 0.2802138924598694), ('next', 0.27479472756385803)]
#
# Word: r
# Vector (first 5 dims shown): [ 0.00662933 -0.00875672  0.01454411 -0.00136716 -0.00361949] ...
# Top 5 similar words: [('im', 0.3811461329460144), ('weeks', 0.35343244671821594), ('say', 0.3116981089115143), ('here', 0.299230694770813), ('co', 0.2815649211406708)]
#
# Word: months
# Vector (first 5 dims shown): [ 0.00505358  0.01198526 -0.01931332 -0.00283486  0.01033996] ...
# Top 5 similar words: [('goes', 0.4059678614139557), ('ldnwarw', 0.39520716667175293), ('use', 0.38507771492004395), ('oru', 0.31892478466033936), ('fa', 0.3112061023712158)]
#
# Word: jackpot
# Vector (first 5 dims shown): [ 0.00553305 -0.00156122 -0.00578151  0.00121852 -0.01134815] ...
# Top 5 similar words: [('melle', 0.37438222765922546), ('std', 0.36889997124671936), ('or', 0.3479901850223541), ('urgent', 0.33915260434150696), ('id', 0.320004403591156)]
#
# Word: had
# Vector (first 5 dims shown): [-0.00304983  0.00447254  0.0108063  -0.00056887  0.00051524] ...
# Top 5 similar words: [('cried', 0.4594927430152893), ('comp', 0.4136587381362915), ('at', 0.3602253198623657), ('goes', 0.3319840729236603), ('promise', 0.32210472226142883)]
#
# Word: hours
# Vector (first 5 dims shown): [-0.0038442  -0.00719823  0.00915765 -0.00402481  0.00057145] ...
# Top 5 similar words: [('if', 0.4156034588813782), ('crazy', 0.36559003591537476), ('around', 0.30384719371795654), ('this', 0.2952233850955963), ('thank', 0.28844496607780457)]
#
# Word: valid
# Vector (first 5 dims shown): [ 0.01951536 -0.00229166 -0.01404203 -0.00409018  0.01230235] ...
# Top 5 similar words: [('valued', 0.39046135544776917), ('per', 0.38219213485717773), ('use', 0.3291606605052948), ('next', 0.31651604175567627), ('update', 0.3093734085559845)]
#
# Word: kl
# Vector (first 5 dims shown): [ 0.00224616 -0.01068771 -0.01159491  0.01438397  0.00413138] ...
# Top 5 similar words: [('send', 0.5276148319244385), ('final', 0.38401395082473755), ('xxx', 0.339098185300827), ('set', 0.3269103765487671), ('all', 0.28698816895484924)]
#
# Word: code
# Vector (first 5 dims shown): [ 0.01600495 -0.01359524  0.00064407  0.00621403 -0.00413174] ...
# Top 5 similar words: [('patent', 0.3398510813713074), ('u', 0.31285619735717773), ('wont', 0.29302963614463806), ('buffet', 0.275554358959198), ('valued', 0.26076677441596985)]
#
# Word: reward
# Vector (first 5 dims shown): [-0.01146238 -0.0072679   0.01545599  0.01143237  0.00234088] ...
# Top 5 similar words: [('crazy', 0.44755348563194275), ('hey', 0.342079222202301), ('amore', 0.3254169225692749), ('did', 0.320948988199234), ('wkly', 0.2953640818595886)]
#
# Word: scotland
# Vector (first 5 dims shown): [-0.00493027 -0.00456302  0.01759583  0.01468837 -0.00529444] ...
# Top 5 similar words: [('days', 0.42587682604789734), ('only', 0.38441920280456543), ('you', 0.38290438055992126), ('watching', 0.3651566803455353), ('free', 0.3011452257633209)]
#
# Word: selected
# Vector (first 5 dims shown): [ 0.00378886 -0.00343812 -0.01932226  0.00151591 -0.00924575] ...
# Top 5 similar words: [('is', 0.3914778530597687), ('oni', 0.3467453122138977), ('wont', 0.3147115111351013), ('searching', 0.3017491400241852), ('chgs', 0.2993345856666565)]
#
# Word: customer
# Vector (first 5 dims shown): [-8.4049709e-05 -1.7094592e-02 -1.3504295e-02  2.3703573e-03
#  -1.9199887e-02] ...
# Top 5 similar words: [('pday', 0.3923741281032562), ('lccltd', 0.353519469499588), ('ur', 0.34823060035705566), ('wif', 0.33583998680114746), ('or', 0.261298269033432)]
#
# Word: network
# Vector (first 5 dims shown): [ 1.4567959e-02  4.6838682e-05 -1.7565819e-02 -1.2884375e-03
#   9.7380644e-03] ...
# Top 5 similar words: [('its', 0.3284362256526947), ('promise', 0.31429365277290344), ('thank', 0.2823851406574249), ('copy', 0.2750372290611267), ('words', 0.27457165718078613)]
#
# Word: valued
# Vector (first 5 dims shown): [ 1.8174514e-02  5.5476605e-05 -9.8741949e-03 -1.4912000e-02
#   6.9042696e-03] ...
# Top 5 similar words: [('be', 0.4762198328971863), ('valid', 0.39046135544776917), ('update', 0.35503247380256653), ('spell', 0.29912158846855164), ('receivea', 0.29852813482284546)]
#
# Word: winner
# Vector (first 5 dims shown): [ 0.01772873 -0.00995948 -0.0113848   0.00026187 -0.01800201] ...
# Top 5 similar words: [('melle', 0.3241782486438751), ('think', 0.3118857741355896), ('latest', 0.2935674488544464), ('jackpot', 0.2831311821937561), ('link', 0.27142974734306335)]
#
# Word: soon
# Vector (first 5 dims shown): [ 0.01153991 -0.01615483  0.01563579 -0.00017553  0.01777497] ...
# Top 5 similar words: [('link', 0.4110744297504425), ('request', 0.37468284368515015), ('remember', 0.2996225357055664), ('membership', 0.27394938468933105), ('treat', 0.271318644285202)]
#
# Word: want
# Vector (first 5 dims shown): [-0.00198302 -0.00988505 -0.01658128  0.00955095  0.00452488] ...
# Top 5 similar words: [('vettam', 0.47658681869506836), ('la', 0.3549298942089081), ('some', 0.3336416780948639), ('times', 0.32821837067604065), ('available', 0.32673048973083496)]
#
# Word: talk
# Vector (first 5 dims shown): [-0.00258055  0.00048541 -0.00779751  0.01115736 -0.01232185] ...
# Top 5 similar words: [('with', 0.3856033980846405), ('tc', 0.34530630707740784), ('st', 0.29687461256980896), ('xxx', 0.27466872334480286), ('goalsteam', 0.2737446129322052)]
#
# Word: about
# Vector (first 5 dims shown): [-0.00790908 -0.01775689  0.01342236 -0.00518522 -0.00024839] ...
# Top 5 similar words: [('you', 0.32031434774398804), ('kim', 0.2611900866031647), ('receivea', 0.2593364715576172), ('then', 0.25245726108551025), ('xxxmobilemovieclubcomnqjkgighjjgcbl', 0.23953483998775482)]
#
# Word: our
# Vector (first 5 dims shown): [ 0.01952028  0.01318822 -0.01843855 -0.01428567 -0.01674764] ...
# Top 5 similar words: [('though', 0.4945025146007538), ('here', 0.3056974709033966), ('months', 0.30385348200798035), ('use', 0.2951658368110657), ('until', 0.286387175321579)]
#
# Word: membership
# Vector (first 5 dims shown): [ 0.00688406  0.00598222  0.00170613 -0.00572366  0.00493138] ...
# Top 5 similar words: [('granted', 0.3700287342071533), ('his', 0.315421998500824), ('only', 0.3085838854312897), ('chances', 0.29964467883110046), ('tc', 0.28622350096702576)]
#
# Word: week
# Vector (first 5 dims shown): [ 0.00184816 -0.00184121  0.01775938 -0.00938238 -0.01470224] ...
# Top 5 similar words: [('usf', 0.3864670693874359), ('world', 0.34528473019599915), ('there', 0.29788246750831604), ('tonight', 0.28661954402923584), ('go', 0.27324995398521423)]
#
# Word: won
# Vector (first 5 dims shown): [ 0.01512084  0.01558288 -0.00504125 -0.00258461  0.01202696] ...
# Top 5 similar words: [('take', 0.3889800012111664), ('nah', 0.36281418800354004), ('date', 0.3572172224521637), ('xxx', 0.31255286931991577), ('treat', 0.2961586117744446)]
#
# Word: urgent
# Vector (first 5 dims shown): [ 0.01828121  0.00256296 -0.00900411  0.01290213  0.01118691] ...
# Top 5 similar words: [('receive', 0.38817650079727173), ('use', 0.3481067419052124), ('message', 0.3412565588951111), ('jackpot', 0.33915266394615173), ('melle', 0.3047802448272705)]
#
# Word: info
# Vector (first 5 dims shown): [-0.00685588  0.00725926  0.00425084  0.0144363  -0.01216062] ...
# Top 5 similar words: [('yes', 0.4365576505661011), ('point', 0.3248930275440216), ('xxxmobilemovieclubcomnqjkgighjjgcbl', 0.2896503508090973), ('claim', 0.2847927510738373), ('some', 0.2807474434375763)]
#
# Word: hl
# Vector (first 5 dims shown): [-0.01432547 -0.01201263  0.0060567   0.00891488 -0.01668078] ...
# Top 5 similar words: [('point', 0.4092582166194916), ('thank', 0.3749498724937439), ('until', 0.3283054530620575), ('remember', 0.2996326982975006), ('from', 0.2945190966129303)]
#
# Word: reply
# Vector (first 5 dims shown): [ 0.01425455  0.01933005  0.01790308 -0.01434532  0.00472676] ...
# Top 5 similar words: [('oni', 0.36951443552970886), ('enough', 0.35111203789711), ('tonight', 0.34260493516921997), ('rcv', 0.32211893796920776), ('a', 0.321016788482666)]
#
# Word: tsandcs
# Vector (first 5 dims shown): [-0.00831503  0.00193429 -0.00176066 -0.01394832  0.01709816] ...
# Top 5 similar words: [('ive', 0.3580637276172638), ('on', 0.3241227865219116), ('they', 0.31716489791870117), ('chances', 0.31135094165802), ('n', 0.29667961597442627)]
#
# Word: days
# Vector (first 5 dims shown): [ 0.00954868  0.01165    -0.01684243  0.00456688 -0.01953098] ...
# Top 5 similar words: [('scotland', 0.42587682604789734), ('latest', 0.37672969698905945), ('home', 0.31336408853530884), ('n', 0.30343347787857056), ('tc', 0.28313374519348145)]
#
# Word: pday
# Vector (first 5 dims shown): [-0.01336993 -0.0172428   0.01721178 -0.00108019 -0.00077219] ...
# Top 5 similar words: [('customer', 0.39237406849861145), ('with', 0.3807864785194397), ('wif', 0.3722003400325775), ('gota', 0.35594987869262695), ('will', 0.311094731092453)]
#
# Word: cost
# Vector (first 5 dims shown): [ 0.00215863  0.00016213 -0.00061375 -0.01687897 -0.00331306] ...
# Top 5 similar words: [('win', 0.4489736258983612), ('oh', 0.39911168813705444), ('did', 0.37717270851135254), ('news', 0.3575509786605835), ('fulfil', 0.3378547430038452)]
#
# Word: csh
# Vector (first 5 dims shown): [ 0.01766116 -0.00457038  0.00879861 -0.00185862  0.00763746] ...
# Top 5 similar words: [('wif', 0.4588116705417633), ('jackpot', 0.3011815547943115), ('now', 0.2774930000305176), ('amore', 0.26003241539001465), ('so', 0.24177059531211853)]
#
# Word: pounds
# Vector (first 5 dims shown): [ 0.01216087 -0.00381011 -0.01314006  0.01062976 -0.00111606] ...
# Top 5 similar words: [('la', 0.46011778712272644), ('eh', 0.41625329852104187), ('dont', 0.3614571690559387), ('promise', 0.36135366559028625), ('callertune', 0.33339184522628784)]
#
# Word: from
# Vector (first 5 dims shown): [-0.01670768  0.01597341  0.0128889   0.00277194 -0.00526866] ...
# Top 5 similar words: [('gon', 0.36219555139541626), ('enough', 0.3599168360233307), ('as', 0.33725738525390625), ('and', 0.3253515064716339), ('hl', 0.2945191264152527)]
#
# Word: cash
# Vector (first 5 dims shown): [-0.00372629 -0.01993563 -0.01162134  0.01812126  0.00408699] ...
# Top 5 similar words: [('bugis', 0.32663917541503906), ('some', 0.32195544242858887), ('will', 0.3076009452342987), ('k', 0.3043670058250427), ('wat', 0.26956823468208313)]
#
# Word: chances
# Vector (first 5 dims shown): [-0.01122592  0.00764387  0.00254526 -0.01695814 -0.01007158] ...
# Top 5 similar words: [('wwwdbuknet', 0.46312418580055237), ('searching', 0.38656705617904663), ('chgs', 0.3408317267894745), ('httpwap', 0.3204798698425293), ('tsandcs', 0.31135091185569763)]
#
# Word: six
# Vector (first 5 dims shown): [ 0.00067815  0.01769654  0.00363762 -0.0015216   0.01440601] ...
# Top 5 similar words: [('co', 0.3450435400009155), ('wonderful', 0.31950822472572327), ('message', 0.2512431740760803), ('hor', 0.25047507882118225), ('k', 0.24885036051273346)]
#
# Word: today
# Vector (first 5 dims shown): [ 0.01825518  0.01785093 -0.01223951  0.00228982 -0.01736731] ...
# Top 5 similar words: [('got', 0.35842496156692505), ('colour', 0.31669506430625916), ('press', 0.2797020673751831), ('friends', 0.2596926689147949), ('b', 0.2587398588657379)]
#
# Word: enough
# Vector (first 5 dims shown): [-0.00827132  0.0198411   0.00344249  0.00112113  0.01172703] ...
# Top 5 similar words: [('from', 0.3599167764186859), ('breather', 0.3564172685146332), ('reply', 0.3511120080947876), ('word', 0.3138725757598877), ('like', 0.3113289177417755)]
#
# Word: cried
# Vector (first 5 dims shown): [-0.00344044  0.00449427 -0.00742031  0.01798828 -0.00934571] ...
# Top 5 similar words: [('had', 0.4594927430152893), ('mobiles', 0.41695138812065125), ('searching', 0.3136683404445648), ('promise', 0.31072354316711426), ('st', 0.3080819547176361)]
#
# Word: k
# Vector (first 5 dims shown): [-0.01218773 -0.01437237  0.00551007  0.01843383  0.00063058] ...
# Top 5 similar words: [('lar', 0.3485366106033325), ('cash', 0.30436697602272034), ('this', 0.2879789173603058), ('with', 0.27880218625068665), ('on', 0.2755003869533539)]
#
# Word: tonight
# Vector (first 5 dims shown): [ 0.01474548  0.00073094  0.00489649 -0.01196733 -0.00810383] ...
# Top 5 similar words: [('xxxmobilemovieclub', 0.36750897765159607), ('reply', 0.3426049053668976), ('breather', 0.3223940432071686), ('he', 0.3037918508052826), ('wet', 0.29279211163520813)]
#
# Word: anymore
# Vector (first 5 dims shown): [-0.00023321  0.0164998   0.00362762  0.00240979 -0.01652777] ...
# Top 5 similar words: [('wat', 0.35844260454177856), ('early', 0.30487653613090515), ('they', 0.2991175949573517), ('now', 0.2870267927646637), ('melle', 0.2750871479511261)]
#
# Word: stuff
# Vector (first 5 dims shown): [-0.01823985 -0.01626967 -0.01868534  0.00371003  0.00416127] ...
# Top 5 similar words: [('friends', 0.37643930315971375), ('how', 0.3018572926521301), ('yes', 0.29482248425483704), ('remember', 0.284278005361557), ('oru', 0.28201308846473694)]
#
# Word: go
# Vector (first 5 dims shown): [ 0.00763384 -0.01242219 -0.00314148 -0.01540179 -0.00338065] ...
# Top 5 similar words: [('im', 0.32856568694114685), ('weeks', 0.28970837593078613), ('here', 0.2815346121788025), ('mobile', 0.27395835518836975), ('week', 0.2732499837875366)]

# %% [markdown]
# ## Use Pre-trained Word2Vec

# %% [markdown]
# We can also use a **pretrained Word2Vec model** (e.g., GoogleNews) for comparison.
# - Pretrained embeddings are trained on huge corpora (millions of words)
# - Useful for small datasets where custom embeddings may be limited
